# %%
from plots_11 import *

# %%
df = pd.read_csv('data/Resultados_Saber_11_nonull.csv')
df
# Out:
#          PERIODO ESTU_TIPODOCUMENTO  ESTU_CONSECUTIVO COLE_AREA_UBICACION  \
# 0          20194                 TI  SB11201940464873               RURAL
# 1          20194                 TI  SB11201940464873               RURAL
# 2          20194                 TI  SB11201940562856              URBANO
# 3          20194                 TI  SB11201940562856              URBANO
# 4          20162                 TI  SB11201620084846              URBANO
# ...          ...                ...               ...                 ...
# 3584317    20221                 CC    AC202210023501              URBANO
# 3584318    20221                 TI    AC202210003698              URBANO
# 3584319    20221                 CC    AC202210034448              URBANO
# 3584320    20221                 TI    AC202210006814              URBANO
# 3584321    20221                 CC    AC202210029659              URBANO
#
#         COLE_BILINGUE COLE_CALENDARIO      COLE_CARACTER  \
# ...

# %%
plot_graphs_saber_once(df, period=20194, department1='BOLIVAR', department2='ANTIOQUIA', department3='ATLANTICO')
# Out:
# {'period': 20194, 'department1': 'BOLIVAR', 'department2': 'ANTIOQUIA', 'department3': 'ATLANTICO'}
# c:\Users\JuanD\Documents\vscode\hackathon\backend\plots_11.py:73: UserWarning: The palette list has more values (8) than needed (3), which may not be intended.
#   sns.histplot(sub_df, x=x, stat='count', kde=True, hue=hue, ax=ax, palette=sns.color_palette(["#0033A0", "#FFCD00", "#CE1126", '#0033A0',
# c:\Users\JuanD\Documents\vscode\hackathon\backend\plots_11.py:73: UserWarning: The palette list has more values (8) than needed (3), which may not be intended.
#   sns.histplot(sub_df, x=x, stat='count', kde=True, hue=hue, ax=ax, palette=sns.color_palette(["#0033A0", "#FFCD00", "#CE1126", '#0033A0',
# c:\Users\JuanD\Documents\vscode\hackathon\backend\plots_11.py:73: UserWarning: The palette list has more values (8) than needed (3), which may not be intended.
# ...
