# %%
from plots_pro import *

# %%
df = pd.read_csv('data/Resultados_Saber_Pro_nonull.csv')
df
# Out:
#         Unnamed: 0  PERIODO ESTU_CONSECUTIVO ESTU_TIPODOCUMENTO  \
# 0                0    20183   EK201830167993                 CC
# 1                1    20183   EK201830168158                 CC
# 2                2    20183   EK201830164354                 CC
# 3                3    20183   EK201830129217                 CC
# 4                4    20183   EK201830138320                 CC
# ...            ...      ...              ...                ...
# 711860      711860    20222   EK202220206584                 CC
# 711861      711861    20222   EK202220148630                 CC
# 711862      711862    20222   EK202220164335                 CC
# 711863      711863    20222   EK202220142587                 CC
# 711864      711864    20222   EK202220116355                 CC
#
#        ESTU_PAIS_RESIDE  ESTU_COD_RESIDE_DEPTO ESTU_DEPTO_RESIDE  \
# 0              COLOMBIA                   73.0            TOLIMA
# 1              COLOMBIA                   68.0         SANTANDER
# 2              COLOMBIA                   11.0            BOGOTÁ
# 3              COLOMBIA                   70.0             SUCRE
# 4              COLOMBIA                   11.0            BOGOTÁ
# ...                 ...                    ...               ...
# 711860         COLOMBIA                   11.0            BOGOTÁ
# 711861         COLOMBIA                   41.0             HUILA
# 711862         COLOMBIA                   54.0   NORTE SANTANDER
# 711863         COLOMBIA                   11.0            BOGOTÁ
# 711864         COLOMBIA                    5.0         ANTIOQUIA
#
#         ESTU_COD_RESIDE_MCPIO ESTU_MCPIO_RESIDE  ESTU_CODDANE_COLE_TERMINO  \
# 0                     73001.0            IBAGUÉ               1.730010e+11
# 1                     68081.0   BARRANCABERMEJA               1.680810e+11
# 2                     11001.0       BOGOTÁ D.C.               1.110010e+11
# 3                     70001.0         SINCELEJO               1.700010e+11
# 4                     11001.0       BOGOTÁ D.C.               3.110010e+11
# ...                       ...               ...                        ...
# 711860                11001.0       BOGOTÁ D.C.               2.111020e+11
# 711861                41396.0          LA PLATA               2.413960e+11
# 711862                54810.0              TIBÚ               1.548100e+11
# 711863                11001.0       BOGOTÁ D.C.               3.230010e+11
# 711864                 5001.0          MEDELLÍN               1.050010e+11
#
#         ...  FAMI_TIENEINTERNET                   FAMI_EDUCACIONMADRE  \
# 0       ...                  Si                               No sabe
# 1       ...                  Si        Técnica o tecnológica completa
# 2       ...                  Si        Educación profesional completa
# 3       ...                  No                               Ninguno
# 4       ...                  Si      Técnica o tecnológica incompleta
# ...     ...                 ...                                   ...
# 711860  ...                  Si    Secundaria (Bachillerato) completa
# 711861  ...                  Si                   Primaria incompleta
# 711862  ...                  No                     Primaria completa
# 711863  ...                  Si    Secundaria (Bachillerato) completa
# 711864  ...                  Si  Secundaria (Bachillerato) incompleta
#
#                      INST_ORIGEN MOD_RAZONA_CUANTITAT_PUNT  \
# 0       NO OFICIAL - CORPORACIÓN                       142
# 1          OFICIAL DEPARTAMENTAL                       185
# 2          OFICIAL DEPARTAMENTAL                       114
# 3       NO OFICIAL - CORPORACIÓN                       120
# 4         NO OFICIAL - FUNDACIÓN                       128
# ...                          ...                       ...
# 711860    NO OFICIAL - FUNDACIÓN                       168
# 711861          OFICIAL NACIONAL                       101
# 711862    NO OFICIAL - FUNDACIÓN                        91
# 711863    NO OFICIAL - FUNDACIÓN                       159
# 711864          OFICIAL NACIONAL                       179
#
#        MOD_COMUNI_ESCRITA_PUNT MOD_COMUNI_ESCRITA_DESEM MOD_INGLES_DESEM  \
# 0                         77.0                      1.0               A1
# 1                        157.0                      3.0              -A1
# 2                        132.0                      2.0               A1
# 3                        127.0                      2.0              -A1
# 4                        165.0                      3.0               A2
# ...                        ...                      ...              ...
# 711860                   125.0                      2.0               A2
# 711861                   149.0                      2.0               A2
# 711862                   135.0                      2.0               A2
# 711863                   162.0                      3.0               B1
# 711864                   156.0                      3.0               A2
#
#         MOD_LECTURA_CRITICA_PUNT MOD_INGLES_PUNT MOD_COMPETEN_CIUDADA_PUNT
# 0                            124           130.0                       153
# 1                            178           106.0                       169
# 2                            139           135.0                       126
# 3                            152           121.0                       127
# 4                            169           159.0                       124
# ...                          ...             ...                       ...
# 711860                       144           156.0                       134
# 711861                       153           134.0                       140
# 711862                       100           132.0                        93
# 711863                       190           178.0                       163
# 711864                       137           134.0                       154
#
# [711865 rows x 58 columns]

# %%
sorted(df['ESTU_DEPTO_RESIDE'].unique())
# Out:
# ['AMAZONAS',
#  'ANTIOQUIA',
#  'ARAUCA',
#  'ATLANTICO',
#  'BOGOTÁ',
#  'BOLIVAR',
#  'BOYACA',
#  'CALDAS',
#  'CAQUETA',
#  'CASANARE',
#  'CAUCA',
#  'CESAR',
#  'CHOCO',
#  'CORDOBA',
#  'CUNDINAMARCA',
#  'GUAINIA',
#  'GUAVIARE',
#  'HUILA',
#  'LA GUAJIRA',
#  'MAGDALENA',
#  'META',
#  'NARIÑO',
#  'NORTE SANTANDER',
#  'PUTUMAYO',
#  'QUINDIO',
#  'RISARALDA',
#  'SAN ANDRES',
#  'SANTANDER',
#  'SUCRE',
#  'TOLIMA',
#  'VALLE',
#  'VAUPES',
#  'VICHADA']

# %%
plot_graphs_saber_pro(period=20183,
					  department1='BOLIVAR', department2='CUNDINAMARCA',
					  department3='NARIÑO', department4='PUTUMAYO')
# Out:
# {'period': 20183, 'department1': 'BOLIVAR', 'department2': 'CUNDINAMARCA', 'department3': 'NARIÑO', 'department4': 'PUTUMAYO'}

# %%
df['ESTU_INST_DEPARTAMENTO'].unique()
# Out:
# array(['BOGOTÁ', 'SANTANDER', 'QUINDIO', 'SUCRE', 'ANTIOQUIA', 'BOYACA',
#        'CAUCA', 'HUILA', 'CUNDINAMARCA', 'VALLE', 'CORDOBA', 'ATLANTICO',
#        'CALDAS', 'BOLIVAR', 'RISARALDA', 'CESAR', 'NORTE SANTANDER',
#        'TOLIMA', 'CAQUETA', 'LA GUAJIRA', 'NARIÑO', 'META', 'MAGDALENA',
#        'CHOCO', 'CASANARE', 'PUTUMAYO'], dtype=object)

# %%
df[df['ESTU_INST_DEPARTAMENTO'] == 'BOGOTÁ']['ESTU_INST_MUNICIPIO'].value_counts()
# Out:
# ESTU_INST_MUNICIPIO
# BOGOTÁ D.C.    301409
# Name: count, dtype: int64

# %%
df[df['ESTU_INST_DEPARTAMENTO'] == 'BOLIVAR']['ESTU_INST_MUNICIPIO'].unique()
# Out:
# array(['CARTAGENA DE INDIAS'], dtype=object)

# %%
df[df['ESTU_INST_MUNICIPIO'].isin(['CARTAGENA DE INDIAS'])]['INST_NOMBRE_INSTITUCION'].unique()
# Out:
# array(['UNIVERSIDAD DE SAN BUENAVENTURA-CARTAGENA',
#        'UNIVERSIDAD DE CARTAGENA-CARTAGENA',
#        'FUNDACION UNIVERSITARIA TECNOLOGICO COMFENALCO - CARTAGENA      -CARTAGENA',
#        'ESCUELA NAVAL DE CADETES"ALMIRANTE PADILLA"-CARTAGENA',
#        'FUNDACION UNIVERSITARIA COLOMBO INTERNACIONAL - UNICOLOMBO-CARTAGENA',
#        'CORPORACION UNIVERSITARIA RAFAEL NUÑEZ-CARTAGENA',
#        'FUNDACION UNIVERSIDAD DE BOGOTA"JORGE TADEO LOZANO"-CARTAGENA',
#        'UNIVERSIDAD TECNOLOGICA DE BOLIVAR-CARTAGENA',
#        "UNIVERSIDAD DEL SINÚ 'Elías Bechara Zainúm' - UNISINÚ-CARTAGENA",
#        'CORPORACION UNIVERSITARIA REGIONAL DEL CARIBE- IAFIC-CARTAGENA',
#        'COLEGIO MAYOR DE BOLIVAR-CARTAGENA',
#        'INSTITUCION UNIVERSITARIA BELLAS ARTES Y CIENCIAS DE BOLIVAR-CARTAGENA',
#        'FUNDACION TECNOLOGICA "ANTONIO DE AREVALO"-CARTAGENA',
#        'INSTITUCIÓN UNIVERSITARIA MAYOR DE CARTAGENA'], dtype=object)
